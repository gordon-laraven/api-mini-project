# %%
# Import dependencies
import requests
import json
import pandas as pd
# import datetime
from datetime import datetime
from datetime import timedelta

# %%
city = input('What city are you expecting to travel to? ')
# Out:
# What city are you expecting to travel to?  los angeles

# %%
nyt_api_key = "ANgt1Outi9JHL92AOO1ZvwTGAG82LZuX"
# New York Times Article API URL
url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

# Get today's date in the format YYYYMMDD
# today = datetime.datetime.today().strftime('%Y%m%d')
today = datetime.today().strftime('%Y%m%d')  # Format as YYYYMMDD
seven_days_ago = (datetime.today() - timedelta(days=7)).strftime('%Y%m%d')

# Build URL
# query_url = f"{url}api-key={api_key}&begin_date={today}&end_date={today}&fq={city_name}"
# query_url="https://api.nytimes.com/svc/topstories/v2/travel.json?api-key=ANgt1Outi9JHL92AOO1ZvwTGAG82LZuX"
# NY Times API URL with the date range (last 7 days)
nyt_url = f"https://api.nytimes.com/svc/search/v2/articlesearch.json?q={city}&begin_date={seven_days_ago}&end_date={today}&api-key={nyt_api_key}" 

# Request articles
articles = requests.get(query_url).json()
# The "response" property in articles contains the actual articles
# list comprehension.
# articles_list = articles["response"]["docs"][0]["snippet"]
articles_list = articles
print(json.dumps(articles_list, indent=4))
# Out:
# {
#     "status": "OK",
#     "copyright": "Copyright (c) 2024 The New York Times Company. All Rights Reserved.",
#     "response": {
#         "docs": [
#             {
#                 "abstract": "Installations of jute sacks or hospital beds have made Ibrahim Mahama a star. Back home, they\u2019re fueling a bold vision.",
#                 "web_url": "https://www.nytimes.com/2024/09/19/arts/design/ibrahim-mahama-artist-ghana-white-cube.html",
#                 "snippet": "Installations of jute sacks or hospital beds have made Ibrahim Mahama a star. Back home, they\u2019re fueling a bold vision.",
#                 "lead_paragraph": "The artist Ibrahim Mahama keeps on the lookout for scrap \u2014 major scrap \u2014 that bears the marks and summons memories of the labor that built Ghana, his country.",
#                 "source": "The New York Times",
#                 "multimedia": [
#                     {
#                         "rank": 0,
# ...

# %%
wapi_key = '9f64593b0b0fa8e9689b566fcf07b95d'

url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Build partial query URL
query_url = f"{url}appid={wapi_key}&units={units}&q="

# Assuming 'city' is taken as input from the user

# set up lists to hold reponse info for:
# latitude, longitude, temp, humidity, and wind speed
lat = []
lon = []
temp = []
humidity = []
wind = []

# Loop through the list of cities and perform a request for data on each
try:
    response = requests.get(query_url + city).json()
    lat.append(response['coord']['lat'])
    lon.append(response['coord']['lon'])
    temp.append(response['main']['temp'])
    humidity.append(response['main']['humidity'])
    wind.append(response['wind']['speed'])

    current_temp = temp[0]

    print(f"The weather of this city is: {city}")
    print(f"The latitude information received is: {lat}")
    print(f"The longitude information received is: {lon}")
    print(f"The temperature information received is: {temp}")
    print(f"The humidity information received is: {humidity}")
    print(f"The wind speed information received is: {wind}")

except:
    print("City does not exist")
# Out:
# The weather of this city is: los angeles
# The latitude information received is: [34.0522]
# The longitude information received is: [-118.2437]
# The temperature information received is: [22.23]
# The humidity information received is: [66]
# The wind speed information received is: [5.66]
